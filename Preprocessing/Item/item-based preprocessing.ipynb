# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os

data = pd.read_csv('games.csv')
data.head()
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000         0
# 3  1355720               Henosis™  Jul 23, 2020        0 - 20000         0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
#결측치(Missing data)
print('전체 데이터 건수:', len(data))
# Out:
# 전체 데이터 건수: 76987

# %%
print('칼럼별 결측치 개수')
len(data) - data.count()
# Out:
# 칼럼별 결측치 개수
# AppID                             0
# Name                              2
# Release date                      0
# Estimated owners                  0
# Peak CCU                          0
# Required age                      0
# Price                             0
# DLC count                         0
# About the game                 2917
# Supported languages               0
# Full audio languages              0
# Reviews                       67625
# Header image                      0
# Website                       40308
# Support url                   38759
# Support email                 12090
# Windows                           0
# Mac                               0
# Linux                             0
# Metacritic score                  0
# Metacritic url                73195
# User score                        0
# Positive                          0
# Negative                          0
# Score rank                    76945
# ...

# %%
# item-based 분석 데이터 칼럼 중 전체 데이터 건 수 대비 상당 수가 
# 결측치로 나와있는 칼럼인 Reviews, Website 등은 삭제한다.
# 또한 분석에 의미 없다고 판단되는 데이터도 삭제한다.
data1 = data.drop(['About the game','Reviews','Header image','Website','Support url','Support email','Metacritic url','Notes','Screenshots'], axis = 'columns')
data1.head()

# %%
# 6개의 열이 삭제되고 총 33개의 칼럼이 남아있다.
# 이제 Primary key로 삼을 AppID에 중복된 데이터가 있는지 확인한다.
data1.duplicated()

# %%
data1[data1.duplicated()]

# %%
# 중복된 데이터는 없음을 확인했다.

# %%
data1.head()

# %%
data1.corr()

# %%
data1.info()

# %%
#data1 = pd.get_dummies(data1, columns=['Genres'])

# 레이블 인코딩
#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()
#data1['Genres'] = le.fit_transform(data1['Genres'])
#data1.head()

# %%
df1 = pd.DataFrame(data1)

# 특정 열에서 True 값만 추출
filtered_data = df1[df1['Mac'] == True]

filtered.data.head()

# %%
data1.head()
